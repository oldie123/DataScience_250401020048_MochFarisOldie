# %% [markdown]
# # Pertemuan 1 - Pengenalan Data Science
#
# **Nama:** Moch Faris Oldie
# **NIM:** 250401020048
# **Kelas:** IF401

# %% [markdown]
# ## Tujuan Praktikum
#
# Notebook ini mengenalkan eksekusi kode Python dasar, variabel, tipe data, list, perulangan, dan fungsi sederhana sebagai fondasi awal Data Science.

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

nama = "Moch Faris Oldie"
angkatan = 2025
ipk = 3.75
aktif = True

print("Nama:", nama)
print("Angkatan:", angkatan)
print("IPK:", ipk)
print("Aktif:", aktif)

tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print()
print("Tools yang digunakan dalam Data Science:")
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")

def perkenalan(nama, prodi, angkatan):
    return f"Hai! Saya {nama} dari prodi {prodi}, angkatan {angkatan}."

hasil = perkenalan("Moch Faris Oldie", "Informatika", 2025)
print()
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama: Moch Faris Oldie
# Angkatan: 2025
# IPK: 3.75
# Aktif: True
#
# Tools yang digunakan dalam Data Science:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub
#
# Hai! Saya Moch Faris Oldie dari prodi Informatika, angkatan 2025.

# %% [markdown]
# ## Kesimpulan
#
# Pada pertemuan ini saya mempelajari dasar penggunaan Python untuk Data Science, mulai dari menampilkan output, menyimpan nilai dalam variabel, memakai list, melakukan perulangan, dan membuat fungsi sederhana. Keterbatasan praktik ini adalah contoh datanya masih sederhana sehingga belum masuk ke analisis data nyata.
